# %%
pip install gensim nltk
# Out:
# Requirement already satisfied: gensim in /usr/local/lib/python3.10/dist-packages (4.3.2)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (3.8.1)
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.10/dist-packages (from gensim) (1.25.2)
# Requirement already satisfied: scipy>=1.7.0 in /usr/local/lib/python3.10/dist-packages (from gensim) (1.11.4)
# Requirement already satisfied: smart-open>=1.8.1 in /usr/local/lib/python3.10/dist-packages (from gensim) (6.4.0)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk) (1.4.0)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk) (2023.12.25)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk) (4.66.2)

# %%
import zipfile
import os
import shutil
import nltk
from nltk.tokenize import sent_tokenize
import gensim
from gensim import corpora

# Download NLTK resources
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
# Provide the path to the zip file
zip_file_path = "/content/Archive2.zip"

# Specify the directory where you want to extract the contents
extracted_dir_path = "/content/extracted/Archive2/Archive2"

# %%
# Create the directory if it doesn't exist
os.makedirs(extracted_dir_path, exist_ok=True)

# %%
# Unzip the file
with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
    zip_ref.extractall(extracted_dir_path)

# %%
print("File extracted successfully!")
# Out:
# File extracted successfully!

# %%
# Function to extract sentences containing the keywords
def extract_sentences_with_keywords(file_path, keywords):
    sentences_with_keywords = []
    with open(file_path, 'r', encoding='latin-1') as file:
        text = file.read()
        sentences = sent_tokenize(text)
        for sentence in sentences:
            if any(keyword in sentence.lower() for keyword in keywords):
                sentences_with_keywords.append(sentence)
    return sentences_with_keywords

# %%
# Keywords to search for
keywords = ['mission', 'church']

# Directory containing the extracted files
extracted_files = os.listdir(extracted_dir_path)

# %%
# Extract sentences containing the keywords from each file
for file_name in extracted_files:
    file_path = os.path.join(extracted_dir_path, file_name)
    if os.path.isfile(file_path):
        sentences_with_keywords = extract_sentences_with_keywords(file_path, keywords)
        if sentences_with_keywords:
            print(f"Sentences containing keywords in {file_name}:")
            for sentence in sentences_with_keywords:
                print(sentence)
            print("\n")
# Out:
# Sentences containing keywords in Chan, Meijean.txt:
# Across the street from the first restaurant was St. Paulâs Episcopal Church and then across the street from the restaurant and one block up was the First Baptist Church and those buildings are still there.
# The Baptist Church is now a restaurant, so we would go over to the park.
# We had friends that we eventually, as probably Junior High, when we began going to the Chinese Community Church.
# Prior to that, our friends were church friends at St. Paulâs Episcopal Church.
# And, ummm, we were in the youth groups for, my sister
#
# and I were in the youth group for both churches.
# Mc: Actually the thing that was probably most meaningful to me as a youngster was
#
# my going to St. Paulâs Episcopal Church.
# hi
#
# Mc: Well, they lucked out because we were involved in church groups.
# That's why, I think, they started having us go to the Chinese Community Church.
# when we started going to the Chinese Community Church, the same thing " happened and there werenât so many boys as there were...there was a large clique of girls about the same age.
# No, when you spoke of the Chinese Church that you just mentioned, was that the Chinese Mission Church on First Avenue?
# About what it was like at the church?
# So, you do remember the old dormitories behind the mission banding.
# As since then, we've been members of the Chinese church so we've maintained that.
# Do you still attend, when you refer to the Chinese Church, do you still attend the one on First Street.
# So they moved from there, moved the church, to 47" Street.
# At this point we have bought a piece of property, our church has, in Tierrasanta.
# We hope to build a new church.
#
#
# Sentences containing keywords in Gin, Harry.txt:
# There was the Chinese Church, I think it was called the Chinese Evangelical Church.
# The church portion was on the ground floor and there was a basement where a Chinese language school was conducted.
# Here I was, a lad of eighteen, a buck sergeant, I ended up being the sergeant major of the squadron, which is a job normally held by a Master Sergeant or something of that rank, kind of the chief administrative non-commissioned officer of the outfit.
# Heâs been with the Atomic Energy Commission ever since graduation from college.
# And he says, "Would you like to be a court commissioner?"
# Tape two, Side two
#
#
# Gin: A court commissioner, by statute, handles matters which are of a more routine variety that a court is called upon to deal with.
# A commissioner however, by the agreement of the parties can do just about anything a judge can do and I was afforded the wonderful experience of being able, through the good graces of the lawyers, to conduct many jury trials.
# Lam: How long were you a court commissioner?
# Gin: I was a court commissioner about twenty-three months.
# Being a court commissioner certainly, Iâve always thought, was the best training in the world to becoming a Judge.
# You are exposed as a court commissioner to just about the full panorama of the law, all kinds of matters.
# Lam: What were some of the memorable cases as court commissioner?
# There was the Chinese Evangelical Church and I believe my parents were members of that church.
# They're looking to the school teachers to provide these sorts of things, the church, while the parents are busy working and trying to satisfy their own wants.
# Gin: There was a gentleman by the name of Frank Wong who was kind of the lay preacher at the church.
# I made it a point to be active in the Chinese Chamber of Commerce and the Chinese Confucian Church and all the other organizations they had.
#
#
# Sentences containing keywords in Hong, Roy Kim.txt:
# the Chinese mission school?
# RH Yeah, the Chinese school __
#
# ML I mean the church.
# Who was ..
#
# RH Well, wasn't in the church.
# ML You went to - well you went to the church on First Avenue.
# RH Yeah
#
# ML The old mission.
# We go down to church and cook.
# They've got four of us we used the church.
# Things from the old church one clean up to another clean up it just moved to different places.
# ML Oh
#
#
#
# RH He used to be very active in church too, He always seems - it seems like the good Lord always have somebody take over somebody, you know, to help us out, to lead us out.
# Do you remember Fourth and
#
# RH  She move out_ She move away
#
#
#
#
# ML _ Before Building, Goldstein had a bordello in that building, How did you guys - did you have cooking facilities in your ...
#
# RH We used the Chinese church on First Street there.
# We always go to church and I,
#
# ML __ Did you know that John A
#
# RH Yeah
#
# ML Because he said he used to help cook there.
# And go to church.
# I met her through the church more than.
# Then Mrs. __ live up there too so we usually pick her up and go to church with her so she don't have to take the...
#
# ML _ So you got married after you got back from the service, right?
# RH â47
#
# ML Were you married in the church?
# RH Baptist church.
# ML Oh, Baptist church?
# Where was the Baptist church?
# Just right close to the church.
#
#
# Sentences containing keywords in Fong, Norman.txt:
# SK: Today is October 20, 2001, My name is Serena Kirk, I am interviewing Mr. Norman Fong at the Chinese Community Church, This is for the San Diego Chinese American Oral History Project.
# People do that _ now they want to build a new church.
#
#
# Sentences containing keywords in Hong, Elizabeth.txt:
# GH When you were living in Chinatown did you attend church down there?
# GH You didn't go to the _
#
# EH No, because my father was a Baptist so we went to a Caucasian church up on Tenth Street.
# It was First Baptist Church.
# Actually I didn't start going to the Chinese church till later.
# We would to the Baptist church and then we would go to the Chinese church, which was at a different hour.
# My dad did try to because we belonged to the Baptist church and there were some ladies there that offered to teach Mother English.
# O.K., so Liz you say your father was a Baptist so you did not go to the Chinese church, actually.
# You weren't members of the Chinese church but you did attend the Mission church occasionally?
# Then they would present this pageant at the Baptist church.
# They took up a collection and then that would be one way of earning some money for our Chinese mission.
# EH Yes, as we got older then we got more active in the mission because that way we kept in touch with the Chinese people because the Baptist church was mostly Caucasian and so we would attend the church - Baptist church - at 9:00 and the Chinese mission is at 1:00.
# After I got married I just changed over to the Chinese church concentrated on that one.
# You dated - you didn't date or there wasn't any inter-racial dating or anything like there is today, Well, when you were going to the Chinese mission did they have the services in English or did they have them both English and Chinese?
# There's enough but not like when the church had their memorial picnic, you know, because that was a really a big occasion too - social event for the community connected with the Chinese mission.
# I think a lot of the social part and everything has to do with the Chinese mission.
# We went out as groups because belonged, you know, to at the time we belonged to the Crusaders - that was a young people's group at Chinese Mission.
# They would come into looking for Chinese food so they would attend the Chinese mission.
# We didn't have what we had - a Chinese USO so the only thing would be the Chinese mission that they would have that.
# I think we met sort of like at the Chinese Mission when they had the Crusaders and we had our social things like dances and things like that.
# It was going to be sponsored by the Chinese mission.
#
#
# Sentences containing keywords in Quon, Rollie.txt:
# YB: Did you attend the Chinese Mission, the church on First Avenue?
# I remember the Sunday School teachers, Mrs, Rimer was the director, Margaret Fanton was our musical, our organist at the church, at the time.
# So that got kind of close and we all got real close there, I remember church was a meeting place for our Boy Scout troop, and for all the other people,
#
# YB: What do you recall about the dormitories behind the mission building?
# My mother joined the churchâs ladies guild and womenâs fellowship, which was a melting pot for them.
#
#
# Sentences containing keywords in Wong, Albert.txt:
# AW: We were at a church, church function.
# AH: Were you active in church at all?
# AW: At the local church, not never in Oregon to speak of.
# Here, active but a member of the Chinese Community church on 47 Street.
# Thatâs about it, for the church conversation.
#
#
# Sentences containing keywords in Yip, Wiley.txt:
# Um, did you attend church services and here it says, the Chinese missionary.
# Right now, that's, well, Murray's in the old mission.
# I used to take the number 2 bus downtown and up to the meetings at the church.
# You know where May Company is in Mission Valley?
# Itâs got the Mission Valley Shopping Center, and itâs got a lot larger.
# They used to go t the theatres and pass the hat in the theatres to collect money stag the a intermission.
# During the intermission between the two movies, we would collect the money and that money was sent to China to â donât know whatever happened to it, as corrupt as things were.
#
#
# Sentences containing keywords in Chan, Norma.txt:
# Then we went dancing at the Mission Beach ballroom and at the Pacific Square on Pacific Highway when a popular name brand band were booked to perform in the city.
# They all remember him what about the missions or the church?
# Yes, we attended church on Sundays.
#
#
# Sentences containing keywords in Hom, Jimmy.txt:
# NF Mrs. Fenton started
#
# JH She would, you know, in the old days she was a missionary in China and after that she came back and do other things and help out in the Chinese mission too.
# Is this behind the Chinese mission?
# JH No, not behind the Chinese mission.
# NF Were you on many bombing missions?
# JH No, I don't do any bombing mission at the beginning, you know.
# The policeman the boys come to Chinese church but they have two sons.
#
#
# Sentences containing keywords in Hom, Baldwin.txt:
# BH Well, usually after a year or so they try to put you into a regular class with regular kids so
#
# anyhow I was there for a year, I guess,
#
# ML Was it you or your father was living at the Mission dormitory?
# So
#
# ML __ So did you go down to the Mission school?
# We have leader take us almost every other week down to Mission Gorge.
# The son __ church
#
# Right.
# He drilled us like soldier boys, you know down at the old church ____ was it- down at Third _ on First Avenue.
# ML _ It was at the church.
# BH In the dormitory behind the church on the second floor we have about eight rooms up
#
# there.
# BH Right at the church.
# BH Say that again
#
# UW _____ like paper
#
# BH I was old enough to, you know, just go to church.
# ML _ Tell us about the Chinese Community Church on First Avenue.
# Only when they first come to the Chinese community, the Chinese mission, and they have no money.
# ML __ So where did they live when they were ...
#
#
#
# BH They lived at the church.
# ML At the church.
# y BH At the church at the dormitory,
#
# ML At the dormitories too.
#
#
# Sentences containing keywords in Hom, Tom.txt:
# Not far from there at First and Market Street was a Chinese church which was called the Chinese Mission at that time.
# The first city he came to was San Francisco, without any money, and the first place he went to was a Presbyterian Mission.
# During his stay in San Francisco at the Presbyterian Mission he was taught Bible stories.
# In the early 1940s my dad leased some land in Mission Valley for a farm (an interruption when the tape was not on)
#
# I was just touching upon the historical aspect of old Chinatown.
# All the department stores moved out to Mission Valley when the shopping centers were developed.
# TH: Dorothy was always involved in church work, like so many other young people.
# Like in some cities stating that if you are of Chinese descent after sundown you couldn't be in the street except if you had permission by your employer.
# I understand there is a matter if you don't like the
#
# Rescue Mission that is in the area so where are you going to
#
# place these people?
# The minority were able to live in the so-called better neighborhoods like Mission Hills, but not as a property owner or renter.
# DEA: Do you want to say one last thing about your church?
# Do you want me to tell you about the diamond jubilee in the church?
# - we were talking about the church as I know it--to reflect the role of the church as I know it.
# The church that I have always known was when it was located at First and Market Streets.
# It was built right next to the church; it was part of the church property.
# It was called the Chinese Mission and it was sponsored and supported by the Congregational Church.
# In the church they had several programs, aside from the religious programs.
# In 1947--that was after the war--some of the people who were involved in the mission felt it was time to have a self-supporting church.
# So that is why it was called the Chinese Congregational Church.
# We became self-supported, so eventually in 1960 we decided to build a new church which is located at 27th and Federal.
# TH We had a building committee--I was on that--and we found a site there where we moved our church.
# We not only use the church just for religious services but we have other activities there.
#
#
# Sentences containing keywords in Fong, Robert.txt:
# MJ Tam Maguna Jackson and lam interviewing Dr, Robert Fung, It is October 28, 2001,
#
# and we are at the Chinese Community Church at the address 1750 Forty-Seventh Street,
#
# San Diego, California, 92102, Where were you born, and where did you spend your
#
# early years,
#
# RF O.K., I was born in San Francisco, right on top of Chinatown, Most of my early years
#
# were spent in San Francisco, California.
# He was always working at the Chinese Church where I spent a lot of time outside of school to play basketball and there.
# O.K., after I finished seminary training for the ministry I was invited by the Chinese
#
# Community Church here in San Diego to become its pastor.
# What was the Chinese and the Mission church like when you arrived?
# the Chinese Mission no longer was a mission but rather had gained its status of a ____ church.
# The church was located there because earlier in the history of San Diego the Chinese lived a little bit below Market Street where most of the Chinese are living.
# RF The dormitory was an adjunct settlement to the finances of the church, Fora long time Chinese men were not allowed to bring their wives or children over from China even if they were married because there was a Chinese Exclusion Law, The Chinese Exclusion Law only permitted five classes of people five classes of Chinese to come over.
# These were the people who needed a place to live in so the church thought very early it was its mission to make some provision for the particular needs of these men.
# Of course, __becausse the Chinese mission building became the Chinese
#
# Historical Society.
# That was the real history of the mission.
# but obviously when our church moved here it was all gone.
# The old mission building became a print shop but maybe there was still the dormitory still operating but it was fast becoming phased out.
# MJ What kind of church programs did you initiate?
# So we established Sunday school, we strengthened the Sunday school, The Sunday school was already established during the mission period by a lady, wonderful lady, by
#
# name of Dale , Who was a school teacher at a private school here in San Diego, She
#
# ____ the director, pushed _ is â continued it as the director, as I understand
#
# for seven years _ at the Chinese church, She was a wonderful woman, She
#
# Â» took care of me and advised on how to do certain things because she had
#
# established a rapport with many of the Chinese families before | came.
# When she wasnât teaching, she would shoot down to the Chinese church and did a lot of things for us.
# In  general most Chinese churches in this country, the United States, started out as missions.
# Many of the Chinese churches in this country which generally would be in large cities like San Francisco, Los Angeles, Portland and so forth.
# Many of those Chinese churches, regardless of their denomination were started by Caucasians to help the Chinese 5 ANGE Soy advantage of having __ right hand .
# The salary for Chinese missions at that time wasnât very good.
# So since I had when I was in college prepared or the mission I had more education which included philosophy and English so I felt that perhaps I could choose a church on a voluntary basis as a volunteer and still be able to a teacher.
# __ __ so I could do that so I combined my career of teaching and minister of this church.
#
#
# Sentences containing keywords in Fong, Ora.txt:
# At the Chinese Community Church, This is for the San Diego Chinese American Oral History project.
# We attended the Chinese church on First Avenue at that time.
# LM Did you participate in any church activities like school or Chinese studies?
# On Sunday __ go to church and come back.
# You didn't mingle unless we went out on an outing or something like that in the church activities.
#
#
# Sentences containing keywords in Tom, Soleng (part about churches).txt:
# They have to be their own--like in Chinese we had--like you say Chee Kung Tong and and Chinese chamber of commerce, Chinese church.
# Did the church represent all of the Chinese...
#
# ST: Yes.
# ST: The church--they call it Chinese Christian Church.
# That's only church you can go and it is on Meyer Street.
# QP: And why did they establish that church?
# Couldn't you go to a regular church?
# QP: So you couldn't go to the local Methodist or--what about the Catholic church?
# So they all go to their own church.
# The Chinese church.
# QP: So the Chinese church in effect was also a response to the exclusion?
# I--how did the Chinese church serve the community outside of actually offering church services?
# ST: They're religion churches.
# Mostly in church educational.
# ST: In, in--really we even have school in the church only.
# The church was established in what year?
# QP: So the social function of the church was largely education.
# And--so when the church was formed you had the church...
#
# ST: Church, the chamber of commerce, the Tong, the Chee Kung Tong, and even Ying On was the late, the last one to come in.
#
#
# Sentences containing keywords in Fong, Pauline.txt:
# We did go to church on Sundays because Mr.K wan would go around the areas and pick up all the children to bring them to church.
# Lt Well, that was very wonderful of Mr. Kwan to take you to church.
# At church do you meet more other ...
#
#
#
#
# PF Chinese children.
# That's why my dad let us go to church, so we could meet other Chinese kids.
# Well you said that you went to the
#
# Chinese community church.
# LT Did you attend the mission school?
# PF The mission school, I think that was started for the new immigrants to learn English.
# PE Well, we went to the record hops or we went to picnics or if the church had something doing we would go to those places.
# I can remember we sometimes after church we would ride the car to the Coronado Ferry back and forth for a nickel.
# I met him at the Chinese church.
# Bid & You were __ =
#
# PF; I knew Jimmy when he was a teen ager and I was a few years younger but I used to help out in the church when we would have get togethers.
# Sometimes the churches from Los Angeles would come down so that we could meet each other.
# You can't meet anybody else so that's why the would get together with the other churches.
#
#
# Sentences containing keywords in Paul, Lim.txt:
# And the past year back to Confucian
#
# Church located in 6th and 6th in Tucson.
# PAUL LIM
# page 22
#
#
#
# Lim: Oh we just very modern, just like that in San
#
# Francisco in the church.
# Like we send our children to
#
# the Chinese Church, we send our children to the
#
# Chinese school to learn Chinese, (cough) we speak
#
# Chinese at home.
# As far as the religion concern,
#
# [that is] have[ing] the church, a pope, and gospel,
#
# and those preacher--but China, Confucianism only is a
#
# Philosophy.
# A Taoism can go to Buddhism's church to
#
# worship, anybody can go to the Taoism temple or the
#
# Buddhism's temple or go even to Catholic church or
#
# Baptist church--so most of the Chinese are like that,
#
# except those really Christian type of person but in
#
# PAUL LIM
# : page 40
#
#
#
# China they don't mind, they only believe the
#
# Philosophy but not believe the religion.
# Even though they go to church I don't know they really
#
# think that way or not.
# Lim: There are many Chinese organization in Tucson,
#
# the highest ranking organization is the Confucian
#
# Church which equivalence to the Chinese Benevolent
#
# Association in the other towns.
# This belong to the
#
# whole community and all the community activity is held
#
# in the Confucian Church, located on Sixth Street and
#
# Sixth Avenue.
# Every other year
#
# they they send out the ballot to those people
#
# they/[who] contribute to the church [and it is they
#
# who ] will [be] consider[ed]as  the voting member.
# Lam: Has the kind of people that join the Confucian Church
#
# changed over the years?
#
#
# Sentences containing keywords in Tom, Jung.txt:
# JM: Did you attend the Chinese Mission Church on First Avenue?
# JT: But my father always ..., you know the Chinese Benevolent Association or the church
#
# JM: They had banquets there?
# Like with the Chinese New Year, the church, they all would participate.
#
#
# Sentences containing keywords in Tom, Carmen Chow.txt:
# And we always had to go to church on Fridays.
# CT: You know, the earliest, and I didn't attend any of those, but | know that now they have a lot of Chinese churches and that's where a lot of the kids are getting together,
#
# GM: Speaking of churches, what kind of church did the family go to?
# Did you keep going to Catholic churches when you were a teenager?
# But now Iâm raising my children Catholic and we are going to church now!
#
#
# Sentences containing keywords in Chung, Lily.txt:
# We are doing it on May 21, 2000, at the Chinese Community Church, Let us
# begin please, What is your name please?
# So it was Mrs. Fanton who was the missionary at the Chinese church.
# IKE With the Chinese Community Church.
# We called it the First Congregational Church in those days.
# The first , | think, helped to built the mission.
# LC The mission.
# It was an adjunct of the First Congregational Church.
# It was a mission and then 1946 we got incorporated into the church.
# RF It was a mission _ __.
# RFE Did you attend the mission school?
# LC Language school
#
# RF _ Did you attend the church services?
#
#
# Sentences containing keywords in Fong, Rhoda Su.txt:
# The date is May 21, 2000 A.D., and we are having the interview in one of the rooms of the Chinese Community Church.
# oO
#
# Did she ever go to the mission to learn English?
# (Va)
#
# I donât know whether she went to the mission, but she participated in the mission womenâs group and she attended church.
# I donât know where she picked up the English from us or...
#
# Because when I came in â50, Miss Jensen was teaching Chinese ladies English up at the church.
# At the mission?
# Well, the mission.
# The mission was our contact with the ...
# Caucasian we met, I think,
# Mother Fanton was the one who entered our lives as the first
#
# who influenced our lives with a mission.
# I canât remember they had dances in the church in the First Congregational Church.
# He was commissioned by all the Chinese in the US to go to the Supreme
#
# Court to fight for this.
# RF Did you give them your permission or did they just give it to you?
# I guess you have to give permission.
# When I had to apply for admission to the teaching program in San Diego State College, I had to -
#
# did they ask you if I committed a felony.
#
#
# Sentences containing keywords in Chan Helen Gong.txt:
# Did you attend - did your family attend any community events either, you know, say, Chinese school or church?
# Oh, yeah, we went to the Chinese church and then, of course, when Rev.
#
#
# Sentences containing keywords in Tang, Esther Don.txt:
# But during the day, there would, of course, be wagons from San Xavier Mission, especially, the Indians with cords of wood, coming into town to sell cords of wood.
# As far as swimming pools, there was Wetmore Swimming Pool, there was Mission Swimming Pool, and they didn't permit the Chinese to go to the swimming pools, we were banned.
# Then around San Xavier Mission there's a place called Furbanks, as I remember-not Burbanks, but Furbanks- where there were quite a number of Chinese farmers growing lettuce and watermelon and such things.
# Peter and Paul Church on Campbell Avenue.
# There was one Chinese church, as I recall, when we were young and going to school.
# That church materialized through the efforts of a fellow by the name of Frank Wong and my uncle, Paul Don.
# (laughs) So between the two of them and some other avid Chinese men, they went on a campaign drive, outside of Arizona, to other states, and brought back money and built that little church.
# It was called the Evangelistical Church, nondenomination.
# And so we sort of look at, for instance, BEOC [Equal Employment Opportunity Commission], the government says, "You have to have a certain percentage of minorities on your payroll."
# The Chinese people have a new church now, on Fort Lowell Road, however, most of us have integrated into the churches of our neighborhood.
# The Overseas Chinese Commission in Taiwan gave me an award.
#
#
# Sentences containing keywords in Hom, John.txt:
# The Chinese Community Church and this is for the San Diego Chinese American Oral History Project, ell us your name again and where you were
# born and when you were born,
#
# JH My name is John Hom and I was born in San Diego, 1927.
# It started with the Chinese Community Church, which was at First Avenue.
# Now our church then evolved to what is now the Historical Society small building.
# JH Yes and helping San Diego sheriffs and law enforcement as much as I can, Still in it, happy with it but I see our people at church have kept together mostly even though they moved out.
# We stayed as centered around the church in my youth.
# So all the people I see in church now and they remember a lot of that.
# Even though we lost contact we've come back together centered around the church.
# The
# good thing about that if we gave them a social hour afterward like a dance and punch and
# stuff even sometimes at the church.
# JF Did you go to the Mission Church - the Chinese Mission Church?
# JH Chinese Mission?
# Yeah that was the church on .
# It was called the Chinese Mission.
# We got in - normally we enjoyed the Boy Scout troop headquarters at the Mission we went out, you know, in the Boy Scout world, learn about .
# They're closing down all the big bases and the ships so my job in there is to
#
# decommission ships with :
#
# Ape You said you were in the Navy.
# We just go from port to port and decommission ships at that time.
# JF Do you remember people - something that I asked - the dormitories behind the church?
# He was a __
#
# Ape They lived in the dormitories by the church.
# Small church, but anyway it's still standing right - and it's our museum now.
# JH At the church,
#
# JH At the church?
# That's__ by just going and spent a week at the Neighborhood Camp of our church.
# Maybe you can't pattern that with church I found out because it isn't like that.
#
#
# Sentences containing keywords in Wen, James.txt:
# I am interviewing James Wen at the Chinese Christian Church.
# They try to be models, to do charity works, and be involved in the Chinese Community Church, where we are right now.
# While he was in China, he brought me to church, and he helped me to get to God (1982).
# So, since then, I started going to church in China.
# I was baptized here, but I started going to church in China.
# That's back in '82,'84, so of course I did not tell anybody I went to church, I was a Christian.
# But maybe I'm only talking about the places that I know in the cities, and in Beijing, the church I went to, called Beijing Chongwenmen Christian Church of course.
# That's the church I know.
# When George Bush was an investor (not George Bush senior), but he was an investor in China, he went to our church, and his daughter Dorothy, was baptized in the church.
# His daughter was baptized in the church, and my pastor, he's retired now, my pastor knows the Bush family very well.
# The government surprised the church in China that I went to, because the government last year, just last year, offered them, said, "Hey, do you need money?
# So the government gave them about two or three million to renovate the church, volunteered!
# The church was surprised.
# The government offers money to renovate the church!
# But, I cannot talk about the churches in the small cities or the countryside.
# I cannot talk about them, but I know the church in Beijing, the church I went to, it has freedom.
# A lot of people nowadays go to church, and the church that I went to before had three or four hundred members, not they have ever three or four thousand people.
# SJ: So, does this church here support anything like that, as far as evangelism overseas?
# JW: We just had a group lead a group by the River Jow, J-O-W, they lead a group [preaching group, missionaries] to China once a year.
# Every year they go to my church in Beijing; yeah, they just came back last week.
# SJ: And how long has this church been here?
# Not here, but in the history of the church.
# They were downtown before, but this church is over ninety years old.
# And how many members does this church have?
# The reason for that is because this is the first church in San Diego, the first Chinese Community Church in San Diego, so all the American-born Chinese in San Diego, like my wifeâs family, came to this church and stayed in this church.
# Right now, Iâve heard there are about six or seven Chinese churches here, but most of the members are new immigrants.
# Maybe most of the immigrant still go to the other Chinese churches with more immigrants.
# We all, in the Chinese Community Church, also my family from China, we all celebrate the Chinese New Year.
# But here in the Chinese Community Church we celebrate Chinese New Year by having a fundraiser; we make it fun, but we also make it a fundraiser event, getting the community support.
# Every year in the Chinese Community Church, we have a Chinese New Year dinner.
# So they celebrate here at the church.
# Thatâs the way we celebrate the Chinese New Year, at the Chinese Community Church.

# %%
import os
import nltk
from nltk.sentiment import SentimentIntensityAnalyzer

# %%
# Download the VADER lexicon for sentiment analysis
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# True

# %%
# Initialize the VADER sentiment analyzer
sid = SentimentIntensityAnalyzer()

# %%
def analyze_sentiment(text):
    """
    Analyzes the sentiment of the given text using VADER sentiment analysis.
    Returns a dictionary containing the compound sentiment score.
    """
    sentiment_scores = sid.polarity_scores(text)
    return sentiment_scores

# %%
# Load and analyze the sentiment for each text file
file_names = [
    "Hom, Tom.txt",
    "Fong, Pauline.txt",
    "Hom, John.txt",
    "Chan, Meijean.txt",
    "Chan Helen Gong.txt",
    "Fong, Robert.txt",
    "Hom, Baldwin.txt",
    "Chung, Lily.txt",
    "Chan, Norma.txt",
    "Fong, Rhoda Su.txt",
    "Hom, Jimmy.txt",
    "Fong, Ora.txt",
    "Fong, Pauline.txt",
    "Fong, Rhoda Su.txt",
    "Fong, Robert.txt",
    "Gin, Harry.txt",
    "Hom, Baldwin.txt",
    "Hom, Jimmy.txt",
    "Hom, John.txt",
    "Hong, Elizabeth.txt",
    "Hong, Roy Kim.txt",
    "Ong-Dean, Mary.txt",
    "Paul, Lim.txt",
    "Quon, Rollie.txt",
    "Tang, Esther Don.txt",
    "Tom, Jung.txt",
    "Wen, James.txt",
    "Wong, Albert.txt",
    "Yip, Wiley.txt"

]

# %%
# Get a list of all text files in the directory
# file_names = [file for file in os.listdir() if file.endswith('.txt')]
# print(file_names)

# %%
# Analyze sentiment for each text file
# extracted_dir = "extracted/Archive2/"
for file_name in file_names:
  file_name = os.path.join(extracted_dir_path, file_name)
  with open(file_name, 'r') as file:
      text = file.read()
      sentiment = analyze_sentiment(text)
      print(f"Sentiment analysis for {file_name}: {sentiment}")
# Out:
# Sentiment analysis for /content/extracted/Archive2/Archive2/Hom, Tom.txt: {'neg': 0.018, 'neu': 0.893, 'pos': 0.089, 'compound': 0.9999}
# Sentiment analysis for /content/extracted/Archive2/Archive2/Fong, Pauline.txt: {'neg': 0.032, 'neu': 0.858, 'pos': 0.11, 'compound': 0.9998}
# Sentiment analysis for /content/extracted/Archive2/Archive2/Hom, John.txt: {'neg': 0.02, 'neu': 0.852, 'pos': 0.128, 'compound': 1.0}
# Sentiment analysis for /content/extracted/Archive2/Archive2/Chan, Meijean.txt: {'neg': 0.02, 'neu': 0.83, 'pos': 0.15, 'compound': 1.0}
# Sentiment analysis for /content/extracted/Archive2/Archive2/Chan Helen Gong.txt: {'neg': 0.038, 'neu': 0.852, 'pos': 0.11, 'compound': 0.9998}
# Sentiment analysis for /content/extracted/Archive2/Archive2/Fong, Robert.txt: {'neg': 0.019, 'neu': 0.891, 'pos': 0.091, 'compound': 0.9997}
# Sentiment analysis for /content/extracted/Archive2/Archive2/Hom, Baldwin.txt: {'neg': 0.039, 'neu': 0.875, 'pos': 0.086, 'compound': 0.9996}
# Sentiment analysis for /content/extracted/Archive2/Archive2/Chung, Lily.txt: {'neg': 0.046, 'neu': 0.877, 'pos': 0.076, 'compound': 0.9979}
# Sentiment analysis for /content/extracted/Archive2/Archive2/Chan, Norma.txt: {'neg': 0.03, 'neu': 0.858, 'pos': 0.112, 'compound': 0.9998}
# Sentiment analysis for /content/extracted/Archive2/Archive2/Fong, Rhoda Su.txt: {'neg': 0.058, 'neu': 0.841, 'pos': 0.101, 'compound': 0.9998}
# Sentiment analysis for /content/extracted/Archive2/Archive2/Hom, Jimmy.txt: {'neg': 0.03, 'neu': 0.882, 'pos': 0.088, 'compound': 0.9999}
# Sentiment analysis for /content/extracted/Archive2/Archive2/Fong, Ora.txt: {'neg': 0.042, 'neu': 0.884, 'pos': 0.075, 'compound': 0.9952}
# Sentiment analysis for /content/extracted/Archive2/Archive2/Fong, Pauline.txt: {'neg': 0.032, 'neu': 0.858, 'pos': 0.11, 'compound': 0.9998}
# Sentiment analysis for /content/extracted/Archive2/Archive2/Fong, Rhoda Su.txt: {'neg': 0.058, 'neu': 0.841, 'pos': 0.101, 'compound': 0.9998}
# Sentiment analysis for /content/extracted/Archive2/Archive2/Fong, Robert.txt: {'neg': 0.019, 'neu': 0.891, 'pos': 0.091, 'compound': 0.9997}
# Sentiment analysis for /content/extracted/Archive2/Archive2/Gin, Harry.txt: {'neg': 0.034, 'neu': 0.846, 'pos': 0.12, 'compound': 1.0}
# Sentiment analysis for /content/extracted/Archive2/Archive2/Hom, Baldwin.txt: {'neg': 0.039, 'neu': 0.875, 'pos': 0.086, 'compound': 0.9996}
# Sentiment analysis for /content/extracted/Archive2/Archive2/Hom, Jimmy.txt: {'neg': 0.03, 'neu': 0.882, 'pos': 0.088, 'compound': 0.9999}
# Sentiment analysis for /content/extracted/Archive2/Archive2/Hom, John.txt: {'neg': 0.02, 'neu': 0.852, 'pos': 0.128, 'compound': 1.0}
# Sentiment analysis for /content/extracted/Archive2/Archive2/Hong, Elizabeth.txt: {'neg': 0.03, 'neu': 0.857, 'pos': 0.113, 'compound': 0.9999}
# Sentiment analysis for /content/extracted/Archive2/Archive2/Hong, Roy Kim.txt: {'neg': 0.02, 'neu': 0.851, 'pos': 0.129, 'compound': 1.0}
# Sentiment analysis for /content/extracted/Archive2/Archive2/Ong-Dean, Mary.txt: {'neg': 0.016, 'neu': 0.832, 'pos': 0.152, 'compound': 0.9999}
# Sentiment analysis for /content/extracted/Archive2/Archive2/Paul, Lim.txt: {'neg': 0.039, 'neu': 0.836, 'pos': 0.124, 'compound': 1.0}
# Sentiment analysis for /content/extracted/Archive2/Archive2/Quon, Rollie.txt: {'neg': 0.029, 'neu': 0.863, 'pos': 0.108, 'compound': 0.9999}
# Sentiment analysis for /content/extracted/Archive2/Archive2/Tang, Esther Don.txt: {'neg': 0.036, 'neu': 0.873, 'pos': 0.091, 'compound': 1.0}
# Sentiment analysis for /content/extracted/Archive2/Archive2/Tom, Jung.txt: {'neg': 0.027, 'neu': 0.74, 'pos': 0.232, 'compound': 1.0}
# Sentiment analysis for /content/extracted/Archive2/Archive2/Wen, James.txt: {'neg': 0.045, 'neu': 0.79, 'pos': 0.165, 'compound': 0.9999}
# Sentiment analysis for /content/extracted/Archive2/Archive2/Wong, Albert.txt: {'neg': 0.034, 'neu': 0.859, 'pos': 0.107, 'compound': 0.9998}
# Sentiment analysis for /content/extracted/Archive2/Archive2/Yip, Wiley.txt: {'neg': 0.041, 'neu': 0.846, 'pos': 0.114, 'compound': 0.9999}

# %%
# for file_name in extracted_files:
file_name = file_names[0]   # file_name = "Hom, Tom.txt"
file_path = os.path.join(extracted_dir_path, file_name)
if os.path.isfile(file_path):
    sentences_with_keywords = extract_sentences_with_keywords(file_path, keywords)
    for sentence in sentences_with_keywords:
      sentiment = analyze_sentiment(sentence)
      print(f"Sentiment analysis for {file_name}: {sentiment}")
# Out:
# Sentiment analysis for Hom, Tom.txt: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Sentiment analysis for Hom, Tom.txt: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Sentiment analysis for Hom, Tom.txt: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Sentiment analysis for Hom, Tom.txt: {'neg': 0.075, 'neu': 0.925, 'pos': 0.0, 'compound': -0.3612}
# Sentiment analysis for Hom, Tom.txt: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Sentiment analysis for Hom, Tom.txt: {'neg': 0.0, 'neu': 0.839, 'pos': 0.161, 'compound': 0.3612}
# Sentiment analysis for Hom, Tom.txt: {'neg': 0.0, 'neu': 0.915, 'pos': 0.085, 'compound': 0.3612}
# Sentiment analysis for Hom, Tom.txt: {'neg': 0.172, 'neu': 0.788, 'pos': 0.039, 'compound': -0.5736}
# Sentiment analysis for Hom, Tom.txt: {'neg': 0.0, 'neu': 0.837, 'pos': 0.163, 'compound': 0.4019}
# Sentiment analysis for Hom, Tom.txt: {'neg': 0.0, 'neu': 0.894, 'pos': 0.106, 'compound': 0.0772}
# Sentiment analysis for Hom, Tom.txt: {'neg': 0.0, 'neu': 0.764, 'pos': 0.236, 'compound': 0.4019}
# Sentiment analysis for Hom, Tom.txt: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Sentiment analysis for Hom, Tom.txt: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Sentiment analysis for Hom, Tom.txt: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Sentiment analysis for Hom, Tom.txt: {'neg': 0.0, 'neu': 0.867, 'pos': 0.133, 'compound': 0.3182}
# Sentiment analysis for Hom, Tom.txt: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Sentiment analysis for Hom, Tom.txt: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Sentiment analysis for Hom, Tom.txt: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Sentiment analysis for Hom, Tom.txt: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Sentiment analysis for Hom, Tom.txt: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Sentiment analysis for Hom, Tom.txt: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
